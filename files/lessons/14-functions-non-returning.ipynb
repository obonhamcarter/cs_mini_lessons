# %% [markdown]
# # Quest 14: Functions Part 2: Non-Returning**CS Quest - Interactive Coding Adventures**Welcome to this interactive lesson! Edit and run all code cells below.

# %% [markdown]
# ## 📖 IntroductionThis lesson is available in two formats:- **Full lesson with explanations**: [View on website](../lessons/14-functions-non-returning.qmd)- **Interactive practice**: Run code cells below to experiment!

# %% [markdown]
# ## 💡 Key ConceptsRefer to the full lesson for detailed explanations.Try editing and running the code cells to practice!

# %%
# Example code cell - edit and run!print('Welcome to Quest 14: Functions Part 2: Non-Returning!')# Add your code below this line:

# %% [markdown]
# ## 🧩 ChallengeTry the challenge from the main lesson and test it here!Click the code cell below to edit and run your solution.

# %%
# Challenge code - write your solution below!# Hint: Check the full lesson for challenge details

# %% [markdown]
# ## 🎓 What You LearnedGreat job! Review the main lesson for a summary of key concepts.## 🚀 What's Next?Ready for the next quest? Go back to the main website to continue your learning adventure!
