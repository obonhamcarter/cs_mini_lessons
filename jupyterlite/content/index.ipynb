# %% [markdown]
# # 🚀 CS Quest - Interactive Coding Adventures
#
# Welcome to the CS Quest JupyterLite environment! This is a full Jupyter notebook interface running entirely in your browser - no installation required!
#
# ## 📚 Available Quests
#
# Click on any lesson notebook to get started:
#
# ### 🌱 Beginner Quests
# 1. **[01-variables.ipynb](01-variables.ipynb)** - Your Coding Backpack
# 2. **02-data-types.ipynb** - Shapes of Information
# 3. **03-conditionals.ipynb** - Choose Your Path
# 4. **04-loops.ipynb** - The Power of Repetition
# 5. **05-lists.ipynb** - Collecting Treasures
#
# ### 🌿 Intermediate Quests
# 6. **06-functions.ipynb** - Magic Spells
# 7. **07-dictionaries.ipynb** - The Key Keeper
# 8. **08-fibonacci.ipynb** - The Golden Sequence
#
# ### 🌳 Advanced Quests
# 9. **09-sorting.ipynb** - Organizing Chaos
# 10. **10-number-game.ipynb** - Can You Guess It?
# 11. **11-recursion.ipynb** - The Echo Chamber
# 12. **12-complexity.ipynb** - Speed Matters
#
# ## 🎯 How to Use
#
# 1. **Run Code Cells**: Click a code cell and press `Shift+Enter` or click the ▶️ button
# 2. **Edit Code**: Click in any code cell to edit it
# 3. **Add Cells**: Use the `+` button in the toolbar
# 4. **Save Work**: Download your notebook using File → Download
#
# ## ✨ Quick Test
#
# Try running this code cell:

# %%
print("🎉 Welcome to CS Quest!")
print("Your interactive Python environment is ready!")

# Try changing the message above and run again!

# %% [markdown]
# ## 🚀 Ready to Start?
#
# Open **01-variables.ipynb** from the file browser on the left to begin your coding adventure!
#
# Happy coding! 💻✨
