# %% [markdown]
# # Quest 1: Variables - Your Coding Backpack 🎒
#
# **CS Quest - Interactive Coding Adventures**
#
# Welcome! In this interactive lesson, you'll learn about variables in Python. You can edit and run all code cells below.

# %% [markdown]
# ## 📖 Introduction: The Adventurer's Backpack
#
# Imagine you're an adventurer setting out on a journey. You have a magical backpack that can hold anything you need—water bottles, maps, treasure, even the number of monsters you've defeated! Each pocket in your backpack has a label, so you always know what's inside.
#
# In Python, **variables** are just like those labeled pockets in your backpack. They help you store information that you can use later in your program!

# %% [markdown]
# ## 💡 What are Variables?
#
# A **variable** is a container that stores a value. Think of it as a labeled box:
# - The **label** is the variable name (like `health`)
# - The **contents** is the value (like `3`)
#
# In Python, creating a variable is super simple:

# %%
# Create some variables
health = 3
player_name = "Hero"
gold = 0

print(f"Health: {health}")
print(f"Name: {player_name}")
print(f"Gold: {gold}")

# %% [markdown]
# ## 🎮 Activity: Create Your Character
#
# Try editing the code below to customize your character, then run it!

# %%
# Create your character's stats - EDIT these values!
character_name = "Robin"
character_level = 1
health_points = 100
magic_power = 15
is_wizard = True

# Display your character
print("=== CHARACTER SHEET ===")
print(f"Name: {character_name}")
print(f"Level: {character_level}")
print(f"Health: {health_points}")
print(f"Magic: {magic_power}")
print(f"Is Wizard: {is_wizard}")

# %% [markdown]
# ## 🔄 Changing Variables
#
# Variables aren't stuck with one value—you can change them! This is where they get powerful.

# %%
# Start with some adventuring stats
health = 100
print(f"Starting health: {health}")

# Oh no! Got attacked by a monster
health = health - 25
print(f"After monster attack: {health}")

# Found a healing potion!
health = health + 50
print(f"After healing potion: {health}")

# %% [markdown]
# ## 🧩 Challenge: The Treasure Split
#
# Three adventurers find treasure! Write code that splits 300 gold coins equally among them and shows how much each gets.

# %%
# Challenge: Divide the treasure
total_treasure = 300
num_adventurers = 3

# Write your code below (hint: use the / operator)
# treasure_per_adventurer = ?

# Uncomment and run when ready:
# print(f"Each adventurer gets: {treasure_per_adventurer} gold")

# %% [markdown]
# ## ✅ Solution
#
# Click the cell below to reveal the answer!

# %%
# SOLUTION
total_treasure = 300
num_adventurers = 3
treasure_per_adventurer = total_treasure / num_adventurers

print(f"Total treasure: {total_treasure} gold")
print(f"Number of adventurers: {num_adventurers}")
print(f"Each adventurer gets: {treasure_per_adventurer} gold")

# %% [markdown]
# ## 🎓 What You Learned
#
# ✨ Variables store values with names
# ✨ You can change variable values
# ✨ Variables make math and logic easier
# ✨ Good variable names make code readable
#
# ## 🚀 What's Next?
#
# Ready to explore more? Check out the next quest: **Data Types - Shapes of Information**!

# %% [markdown]
# # Quest 1: Variables - Your Coding Backpack 🎒
#
# **CS Quest - Interactive Coding Adventures**
#
# Welcome! In this interactive lesson, you'll learn about variables in Python. You can edit and run all code cells below.

# %% [markdown]
# ## 📖 Introduction: The Adventurer's Backpack
#
# Imagine you're an adventurer setting out on a journey. You have a magical backpack that can hold anything you need—water bottles, maps, treasure, even the number of monsters you've defeated! Each pocket in your backpack has a label, so you always know what's inside.
#
# In Python, **variables** are just like those labeled pockets in your backpack. They help you store information that you can use later in your program!

# %% [markdown]
# ## 💡What are Variables?
#
# A **variable** is a container that stores a value. Think of it as a labeled box:
# - The **label** is the variable name (like `health`)
# - The **contents** is the value (like `3`)
#
# In Python, creating a variable is super simple:

# %%
# Create some variables
health = 3
player_name = "Hero"
gold = 0

print(f"Health: {health}")
print(f"Name: {player_name}")
print(f"Gold: {gold}")

# %% [markdown]
# ## 🎮 Activity: Create Your Character
#
# Try editing the code below to customize your character, then run it!

# %%
# Create your character's stats - EDIT these values!
character_name = "Robin"
character_level = 1
health_points = 100
magic_power = 15
is_wizard = True

# Display your character
print("=== CHARACTER SHEET ===")
print(f"Name: {character_name}")
print(f"Level: {character_level}")
print(f"Health: {health_points} HP")
print(f"Magic: {magic_power} MP")
print(f"Is Wizard: {is_wizard}")
print("=" * 23)

# %% [markdown]
# ### 🎯 Challenge
#
# Try modifying the character above to:
# 1. Change the name to your own name
# 2. Set the level to 5
# 3. Give 200 health points
# 4. Change magic power to 50

# %% [markdown]
# ## 👨‍💻 Variables in Action
#
# Variables become really powerful when you use them in calculations:

# %%
# Starting values
gold = 10
enemies_defeated = 0

print(f"Starting gold: {gold}")
print(f"Enemies defeated: {enemies_defeated}")
print()

# You found a treasure chest!
gold = gold + 25
print("🎁 You found a treasure chest! +25 gold")
print(f"Gold now: {gold}")
print()

# You defeated an enemy!
enemies_defeated = enemies_defeated + 1
print("⚔️ You defeated an enemy!")
print(f"Enemies defeated: {enemies_defeated}")
print()

# Another battle!
enemies_defeated = enemies_defeated + 1
gold = gold + 5
print("⚔️ Another enemy defeated! +5 gold")
print(f"Total enemies defeated: {enemies_defeated}")
print(f"Total gold: {gold}")

# %% [markdown]
# ## 🧩 Puzzle Time!
#
# Figure out what this code will print **before** you run it:

# %%
# Can you predict the output?
x = 5
y = 10
z = x + y

x = 20

print(f"x = {x}")
print(f"y = {y}")
print(f"z = {z}")

# Why is z still 15 and not 30?
# Think about it, then run to check!

# %% [markdown]
# ### 🔑 Solution
#
# The answer is:
# ```
# x = 20
# y = 10
# z = 15
# ```
#
# **Why?** When we calculated `z = x + y`, x was 5 and y was 10, so z became 15.
#
# When we later changed `x = 20`, it **didn't** change z! The variable z still holds the original calculation result.
#
# **Variables store values, not formulas!**

# %% [markdown]
# ## 🎯 Key Takeaways
#
# ✅ Variables are labeled containers that store values
# ✅ Use the `=` sign to assign values to variables
# ✅ Variable names should be descriptive and follow naming rules
# ✅ You can update variables by assigning new values
# ✅ Variables store values, not formulas
#
# **Ready for more?** Try Quest 2: Data Types!

# %% [markdown]
# ## 🚀 Practice Exercise
#
# Create variables for your favorite video game character or superhero:

# %%
# Your turn! Create variables for your favorite character
favorite_hero = "Spider-Man"
power_level = 9000
can_fly = False
catchphrase = "With great power comes great responsibility"

# Add more and have fun!
print(f"Hero: {favorite_hero}")
print(f"Power Level: {power_level}")
print(f"Can Fly: {can_fly}")
print(f"Catchphrase: {catchphrase}")
